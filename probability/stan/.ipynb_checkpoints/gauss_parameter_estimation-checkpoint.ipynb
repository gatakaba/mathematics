# %% [markdown]
# # ガウス分布のパラメータ推定
#
#
# ## データ
# - N : データの個数
# - y : データの値
#
# ## パラメータ
# - mu : 平均値
# - s2 : 分散
#
# ## モデル
# $p(\sigma) = cauchy(\sigma,0.5)$
#
# $p(y_{n}|\mu,\sigma) = N(y_{n}|\mu,\sigma)$

# %%
# %matplotlib inline

# %%
import pystan
import numpy as np
import matplotlib.pyplot as plt

# %%
stan_code = """
data{
    int<lower=0> N;
    real y[N];
}

parameters {
    real mu;
    real <lower =0> s2;
}

model {
    s2 ~ cauchy(0,5);
    y ~ normal(mu,sqrt(s2));
}
"""

stan_dat = {'N': 1000,
               'y': np.random.normal(1,3,size=1000)
              }

fit = pystan.stan(model_code=stan_code, data=stan_dat,iter=1000, chains=4)

print(fit)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-9dedc08eddd1> in <module>()
#      18               }
#      19
# ---> 20 fit = pystan.stan(model_code=stan_code, data=stan_dat,iter=1000, chains=4)
#      21
#      22 print(fit)
#
# /Users/kaba32/.pyenv/versions/anaconda3-4.0.0/lib/python3.5/site-packages/pystan/api.py in stan(file, model_name, model_code, fit, data, pars, chains, iter, warmup, thin, init, seed, algorithm, control, sample_file, diagnostic_file, verbose, boost_lib, eigen_lib, n_jobs, **kwargs)
#     370         m = StanModel(file=file, model_name=model_name, model_code=model_code,
#     371                       boost_lib=boost_lib, eigen_lib=eigen_lib,
# --> 372                       verbose=verbose)
#     373     # check that arguments in kwargs are valid
#     374     valid_args = {"chain_id", "init_r", "test_grad", "append_samples", "enable_random_init",
#
# /Users/kaba32/.pyenv/versions/anaconda3-4.0.0/lib/python3.5/site-packages/pystan/model.py in __init__(self, file, charset, model_name, model_code, stanc_ret, boost_lib, eigen_lib, verbose, obfuscate_model_name, extra_compile_args)
#     308
#     309         try:
# --> 310             build_extension.run()
#     311         finally:
#     312             if redirect_stderr:
#
# /Users/kaba32/.pyenv/versions/anaconda3-4.0.0/lib/python3.5/distutils/command/build_ext.py in run(self)
#     336
#     337         # Now actually compile and link everything.
# --> 338         self.build_extensions()
#     339
#     340     def check_extensions_list(self, extensions):
#
# /Users/kaba32/.pyenv/versions/anaconda3-4.0.0/lib/python3.5/distutils/command/build_ext.py in build_extensions(self)
#     445             self._build_extensions_parallel()
#     446         else:
# --> 447             self._build_extensions_serial()
#     448
#     449     def _build_extensions_parallel(self):
#
# /Users/kaba32/.pyenv/versions/anaconda3-4.0.0/lib/python3.5/distutils/command/build_ext.py in _build_extensions_serial(self)
#     470         for ext in self.extensions:
#     471             with self._filter_build_errors(ext):
# --> 472                 self.build_extension(ext)
#     473
#     474     @contextlib.contextmanager
#
# /Users/kaba32/.pyenv/versions/anaconda3-4.0.0/lib/python3.5/distutils/command/build_ext.py in build_extension(self, ext)
#     530                                          debug=self.debug,
#     531                                          extra_postargs=extra_args,
# --> 532                                          depends=ext.depends)
#     533
#     534         # XXX outdated variable, kept here in case third-part code
#
# /Users/kaba32/.pyenv/versions/anaconda3-4.0.0/lib/python3.5/distutils/ccompiler.py in compile(self, sources, output_dir, macros, include_dirs, debug, extra_preargs, extra_postargs, depends)
#     572             except KeyError:
#     573                 continue
# --> 574             self._compile(obj, src, ext, cc_args, extra_postargs, pp_opts)
#     575
#     576         # Return *all* object filenames, not just the ones we just built.
#
# /Users/kaba32/.pyenv/versions/anaconda3-4.0.0/lib/python3.5/distutils/unixccompiler.py in _compile(self, obj, src, ext, cc_args, extra_postargs, pp_opts)
#     114         try:
#     115             self.spawn(compiler_so + cc_args + [src, '-o', obj] +
# --> 116                        extra_postargs)
#     117         except DistutilsExecError as msg:
#     118             raise CompileError(msg)
#
# /Users/kaba32/.pyenv/versions/anaconda3-4.0.0/lib/python3.5/distutils/ccompiler.py in spawn(self, cmd)
#     907
#     908     def spawn(self, cmd):
# --> 909         spawn(cmd, dry_run=self.dry_run)
#     910
#     911     def move_file(self, src, dst):
#
# /Users/kaba32/.pyenv/versions/anaconda3-4.0.0/lib/python3.5/distutils/spawn.py in spawn(cmd, search_path, verbose, dry_run)
#      34     cmd = list(cmd)
#      35     if os.name == 'posix':
# ---> 36         _spawn_posix(cmd, search_path, dry_run=dry_run)
#      37     elif os.name == 'nt':
#      38         _spawn_nt(cmd, search_path, dry_run=dry_run)
#
# /Users/kaba32/.pyenv/versions/anaconda3-4.0.0/lib/python3.5/distutils/spawn.py in _spawn_posix(cmd, search_path, verbose, dry_run)
#     136         while True:
#     137             try:
# --> 138                 pid, status = os.waitpid(pid, 0)
#     139             except OSError as exc:
#     140                 if not DEBUG:
#
# KeyboardInterrupt:

# %%
fit.plot()
plt.show()
