# %% [markdown]
# # カルマンフィルタ
#
# ## モデル
# - $\mu_{t} \sim Normal(\mu_{t-1},\sigma_{\mu}) $
#
# - $Y_{t} \sim Normal(\mu_{t},\sigma_{Y}) $

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (20, 12)

# %%
import pystan
import numpy as np
import matplotlib.pyplot as plt

# %%
stan_code1 = """
data {
    int T;
    int T_pred;
    vector[T] Y;
}

parameters {
    vector[T] mu;
    real<lower=0> s_mu;
    real<lower=0> s_Y;
}

model {
    mu[2:T] ~ normal(mu[1:(T-1)],s_mu);
    Y ~ normal(mu,s_Y);
}
generated quantities{
    vector[T+T_pred] mu_all;
    vector[T_pred] y_pred;
    mu_all[1:T]=mu;
    for(t in 1:T_pred){
        mu_all[T+t] =normal_rng(mu_all[T+t-1],s_mu);
        y_pred[t] =normal_rng(mu_all[T+t-1],s_Y);
    }
}
"""

# %%
stan_code2 = """
data {
    int T;
    vector[T] Y;
}

parameters {
    vector[T] mu;
    real<lower=0> s_mu;
    real<lower=0> s_Y;
}

model {
    mu[3:T] ~ normal(2*mu[2:(T-1)]-mu[1:(T-2)],s_mu);
    Y ~ normal(mu,s_Y);
}

"""

# %%
stan_code3 = """
data {
    int T;
    vector[T] Y;
}

parameters {
    vector[T] mu;
    real<lower=0> s_mu;
    real<lower=0> s_Y;
}

model {
    mu[4:T] ~ normal(3*mu[3:(T-1)] -3*mu[2:(T-2)] +  mu[1:(T-3)],s_mu);
    Y ~ normal(mu,s_Y);
}

"""

# %%
y=np.cumsum(np.random.normal(3,10,size=100))
stan_dat = {
    'T': 100,
    'Y': y
}

fit1 = pystan.stan(model_code = stan_code1, data = stan_dat, iter = 2500, chains = 4)
#fit2 = pystan.stan(model_code = stan_code2, data = stan_dat, iter = 2500, chains = 4)
#fit3 = pystan.stan(model_code = stan_code3, data = stan_dat, iter = 2500, chains = 4)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-122-ca21a5b9e651> in <module>()
#       7 }
#       8
# ----> 9 fit1 = pystan.stan(model_code = stan_code1, data = stan_dat, iter = 2500, chains = 4)
#      10 #fit2 = pystan.stan(model_code = stan_code2, data = stan_dat, iter = 2500, chains = 4)
#      11 #fit3 = pystan.stan(model_code = stan_code3, data = stan_dat, iter = 2500, chains = 4)
#
# /Users/kaba32/.pyenv/versions/anaconda3-4.0.0/lib/python3.5/site-packages/pystan/api.py in stan(file, model_name, model_code, fit, data, pars, chains, iter, warmup, thin, init, seed, algorithm, control, sample_file, diagnostic_file, verbose, boost_lib, eigen_lib, n_jobs, **kwargs)
#     382                      sample_file=sample_file, diagnostic_file=diagnostic_file,
#     383                      verbose=verbose, algorithm=algorithm, control=control,
# --> 384                      n_jobs=n_jobs, **kwargs)
#     385     return fit
#
# /Users/kaba32/.pyenv/versions/anaconda3-4.0.0/lib/python3.5/site-packages/pystan/model.py in sampling(self, data, pars, chains, iter, warmup, thin, seed, init, sample_file, diagnostic_file, verbose, algorithm, control, n_jobs, **kwargs)
#     665             raise ValueError("Algorithm must be one of {}".format(algorithms))
#     666
# --> 667         fit = self.fit_class(data)
#     668
#     669         m_pars = fit._get_param_names()
#
# stanfit4anon_model_2194407bafce6b78a6d9d93aac858e0d_2695233349806446308.pyx in stanfit4anon_model_2194407bafce6b78a6d9d93aac858e0d_2695233349806446308.StanFit4Model.__cinit__ (/var/folders/ht/4q3ptj1j68596k9mgzl622c80000gp/T/tmpssvegolj/stanfit4anon_model_2194407bafce6b78a6d9d93aac858e0d_2695233349806446308.cpp:8694)()
#
# RuntimeError: variable does not exist; processing stage=data initialization; variable name=T_pred; base type=int

# %%
ms1=fit1.extract()
ms2=fit2.extract()
ms3=fit3.extract()

# %%
mu1=ms1["mu"]
mu2=ms2["mu"]
mu3=ms3["mu"]

# %%
mu1_mean=np.mean(mu1,axis=0)
mu1_sigma=np.std(mu1,axis=0)

mu2_mean=np.mean(mu2,axis=0)
mu2_sigma=np.std(mu2,axis=0)

mu3_mean=np.mean(mu3,axis=0)
mu3_sigma=np.std(mu3,axis=0)

# %%
x=np.linspace(0,1,100)

plt.subplot(1,3,1)
plt.plot(x,mu1_mean,linewidth=3)
plt.fill_between(x,mu1_mean-mu1_sigma*3,mu1_mean+mu1_sigma*3,alpha=0.5)
plt.subplot(1,3,2)
plt.plot(x,mu2_mean,linewidth=3)
plt.fill_between(x,mu2_mean-mu2_sigma*3,mu2_mean+mu2_sigma*3,alpha=0.5)

plt.subplot(1,3,3)
plt.plot(x,mu3_mean,linewidth=3)
plt.fill_between(x,mu3_mean-mu3_sigma*3,mu3_mean+mu3_sigma*3,alpha=0.5)



#plt.plot(x,y,"ro-",linewidth=3)
