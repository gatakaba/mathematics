# %% [markdown]
# # ガウス分布
#
#
# ## データ
# - N : データの個数
# - y : データの値
#
# ## パラメータ
# - mu : 平均値
# - s2 : 分散
#
# ## モデル
# $\sigma \sim Cauchy(0,0.5)$
#
#
# $y_{n} \sim  N(\mu,\sigma)$

# %%
# %matplotlib inline

# %%
import pystan
import numpy as np
import matplotlib.pyplot as plt

# %%
stan_code = """
data {
    int < lower = 0 > N;
    vector[N] Y;
}

parameters {
    real mu;
    real < lower = 0 > s2;
}

model {
    target += cauchy_lpdf(s2|0, 5);
    
    for (n in 1:N){
    target += normal_lpdf(Y[n]|mu, sqrt(s2));

    }
}
"""


stan_dat = {
    'N': 1000,
    'Y': np.random.normal(1, 3, size = 1000)
}

fit = pystan.stan(model_code = stan_code, data = stan_dat, iter = 2500, chains = 4)
print(fit)
# Out:
# Inference for Stan model: anon_model_c54bfa216dd980e4656acd4966bb1cba.
# 4 chains, each with iter=2500; warmup=1250; thin=1;
# post-warmup draws per chain=1250, total post-warmup draws=5000.
#
#        mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# mu     0.96  1.9e-3   0.09   0.78    0.9   0.96   1.02   1.14   2420    1.0
# s2     8.77  7.3e-3    0.4   8.03   8.49   8.76   9.03   9.57   2958    1.0
# lp__  -2506    0.02    1.0  -2508  -2506  -2505  -2505  -2505   2894    1.0
#
# Samples were drawn using NUTS at Tue Nov 15 22:49:25 2016.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).

# %%
la = fit.extract(permuted=True)  # return a dictionary of arrays
print(np.mean(la["mu"]),np.std(la["mu"]))
# Out:
# 0.959215172337 0.0926817784743

# %%
plt.rcParams['figure.figsize'] = (20, 12)
fit.plot()
plt.show()
